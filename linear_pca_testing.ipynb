# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(columns=['x', 'y'])
df.loc[0]=[1,3]
df.loc[1]=[1.5,4.3]
df.loc[2]=[2,4.7]
df.loc[3]=[2.5,4.9]
df.loc[4]=[3,5]
df.loc[5]=[3.5,4.9]
df.loc[6]=[4,4.7]
df.loc[7]=[4.5,4.3]
df.loc[8]=[5,3]

X = df[['x', 'y']]
features = X.T 
covariance_matrix = np.cov(features)
print(covariance_matrix)

eig_vals, eig_vecs = np.linalg.eig(covariance_matrix)

print('Eigenvectors \n%s' %eig_vecs)

print('\nEigenvalues \n%s' %eig_vals)

eig_vals[0] / sum(eig_vals)

projected_X = eig_vecs.T[0]
result = pd.DataFrame(projected_X, columns=['PC1'])
result['y-axis'] = 0.0
result.head(10)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.lmplot('PC1', 'y-axis', data=result, fit_reg=False,
           scatter_kws={"s": 50})

# title
plt.title('PCA result')
# Out:
# [[1.875      0.        ]
#  [0.         0.61361111]]
# Eigenvectors
# [[1. 0.]
#  [0. 1.]]
#
# Eigenvalues
# [1.875      0.61361111]
# Text(0.5,1,'PCA result')

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(columns=['x', 'y'])
df.loc[0]=[12,12]
df.loc[1]=[18,18]
df.loc[2]=[30,30]
df.loc[3]=[42,42]
df.loc[4]=[50,50]
df.loc[5]=[60,60]
df.loc[6]=[70,70]
df.loc[7]=[80,80]
df.loc[8]=[90,90]
df.loc[9]=[100,100]

X = df[['x', 'y']]
import numpy as np

features = X.T 
covariance_matrix = np.cov(features)
print(covariance_matrix)

eig_vals, eig_vecs = np.linalg.eig(covariance_matrix)

print('Eigenvectors \n%s' %eig_vecs)

print('\nEigenvalues \n%s' %eig_vals)

eig_vals[0] / sum(eig_vals)

projected_X = eig_vecs.T[0]
result = pd.DataFrame(projected_X, columns=['PC1'])
result['y-axis'] = 0.0
printresult.head(10)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.lmplot('PC1', 'y-axis', data=result, fit_reg=False,  # x-axis, y-axis, data, no line
           scatter_kws={"s": 50}) # color

# title
plt.title('PCA result')
# Out:
# [[906.84444444 906.84444444]
#  [906.84444444 906.84444444]]
# Eigenvectors
# [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]
#
# Eigenvalues
# [ 1.81368889e+03 -2.27373675e-13]
# Text(0.5,1,'PCA result')
